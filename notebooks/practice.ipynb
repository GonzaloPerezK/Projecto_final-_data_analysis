# %% [markdown]
# ## Práctica
#
# Puedes utilizar este notebook para analisar el dataset propuesto

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# ----------------------------------------------------
# Configuración básica de la página
# ----------------------------------------------------
st.set_page_config(
    page_title="California Housing - Análisis Interactivo",
    page_icon="🏠",
    layout="wide",
)

st.title("🏠 Análisis Interactivo de Precios de Vivienda en California")
st.write(
    """
Esta aplicación utiliza el *dataset* **California Housing** de `scikit-learn` para
explorar la relación entre características sociodemográficas y el valor mediano
de las viviendas (**MedHouseVal**).

En la barra lateral podés ajustar filtros y observar cómo cambian los datos,
las estadísticas descriptivas y los gráficos.
"""
)

# ----------------------------------------------------
# Fase 1: Carga y vista general de los datos
# ----------------------------------------------------


@st.cache_data
def load_data() -> pd.DataFrame:
    """
    Carga el dataset de California desde scikit-learn y lo devuelve como un DataFrame.
    """
    data = fetch_california_housing(as_frame=True)
    df = data.frame.copy()
    # El DataFrame ya incluye las columnas de características y la columna objetivo `MedHouseVal`
    return df


df_california = load_data()

st.subheader("Vista general del dataset")

col_a, col_b = st.columns(2)

with col_a:
    st.markdown("**Primeras 5 filas del dataset:**")
    st.dataframe(df_california.head())

with col_b:
    st.markdown("**Información general y tipos de datos:**")
    st.write(df_california.dtypes)

st.markdown("**Valores faltantes por columna:**")
st.write(df_california.isna().sum())

st.markdown("---")

# ----------------------------------------------------
# Fase 2: Análisis descriptivo interactivo (widgets)
# ----------------------------------------------------

st.sidebar.header("Filtros de exploración")

st.sidebar.write(
    """
Ajustá los filtros para explorar cómo cambian los datos
y las métricas descriptivas del valor de la vivienda.
"""
)

# Slider para filtrar por HouseAge
age_min = int(df_california["HouseAge"].min())
age_max = int(df_california["HouseAge"].max())

age_range = st.sidebar.slider(
    "Rango de Edad Mediana de la Casa (HouseAge)",
    min_value=age_min,
    max_value=age_max,
    value=(age_min, age_max),
    step=1,
)

# Filtro por latitud mínima (vecindario aproximado)
lat_min_global = float(df_california["Latitude"].min())
lat_max_global = float(df_california["Latitude"].max())

st.sidebar.markdown("### Filtro por vecindario (Latitud mínima)")
min_latitude = st.sidebar.number_input(
    "Latitud mínima",
    min_value=lat_min_global,
    max_value=lat_max_global,
    value=lat_min_global,
    step=0.5,
    help="Se filtrarán las viviendas cuya latitud sea mayor o igual a este valor.",
)

# Aplicar filtros
filtered_df = df_california[
    (df_california["HouseAge"] >= age_range[0])
    & (df_california["HouseAge"] <= age_range[1])
    & (df_california["Latitude"] >= min_latitude)
]

st.subheader("Datos filtrados")

st.write(
    f"Filas resultantes después de aplicar los filtros: **{filtered_df.shape[0]}**"
)
st.dataframe(filtered_df.head())

# Resumen descriptivo de MedHouseVal
st.subheader("Resumen descriptivo de MedHouseVal (datos filtrados)")

if not filtered_df.empty:
    mediana_valor = filtered_df["MedHouseVal"].median()
    rango_valor = filtered_df["MedHouseVal"].max() - filtered_df["MedHouseVal"].min()

    col1, col2 = st.columns(2)
    with col1:
        st.metric("Mediana de MedHouseVal", f"{mediana_valor:.3f}")
    with col2:
        st.metric("Rango (máx - mín) de MedHouseVal", f"{rango_valor:.3f}")
else:
    st.warning(
        "No hay datos con los filtros seleccionados. Ajustá los filtros en la barra lateral."
    )

st.markdown("---")

# ----------------------------------------------------
# Fase 3: Visualización dinámica
# ----------------------------------------------------

# 3.1 Histograma de MedHouseVal
st.subheader("Distribución del valor mediano de la vivienda (MedHouseVal)")

if not filtered_df.empty:
    fig_hist, ax_hist = plt.subplots()
    ax_hist.hist(filtered_df["MedHouseVal"], bins=30)
    ax_hist.set_xlabel("MedHouseVal (cientos de miles de USD)")
    ax_hist.set_ylabel("Frecuencia")
    ax_hist.set_title("Histograma de MedHouseVal (datos filtrados)")
    st.pyplot(fig_hist)
else:
    st.info(
        "No se puede mostrar el histograma porque no hay datos con los filtros actuales."
    )

# 3.2 Scatter plot MedInc vs MedHouseVal
st.subheader("Relación entre ingresos y valor de la vivienda")

if not filtered_df.empty:
    fig_scatter, ax_scatter = plt.subplots()
    ax_scatter.scatter(
        filtered_df["MedInc"],
        filtered_df["MedHouseVal"],
        alpha=0.3,
    )
    ax_scatter.set_xlabel("MedInc (decenas de miles de USD)")
    ax_scatter.set_ylabel("MedHouseVal (cientos de miles de USD)")
    ax_scatter.set_title("MedInc vs MedHouseVal (datos filtrados)")
    st.pyplot(fig_scatter)
else:
    st.info(
        "No se puede mostrar el gráfico de dispersión porque no hay datos con los filtros actuales."
    )

st.markdown("---")

# 3.3 Mapa geográfico (extra)
st.subheader("Mapa geográfico de las viviendas filtradas (opcional)")

if not filtered_df.empty:
    st.caption("Cada punto representa un grupo de bloques según Latitude y Longitude.")
    map_df = filtered_df[["Latitude", "Longitude"]].rename(
        columns={"Latitude": "lat", "Longitude": "lon"}
    )
    st.map(map_df)
else:
    st.info("No se puede mostrar el mapa porque no hay datos con los filtros actuales.")
# Out:
# 2025-11-30 20:50:38.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.344 No runtime found, using MemoryCacheStorageManager
# 2025-11-30 20:50:38.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.381 Serialization of dataframe to Arrow table was unsuccessful. Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# Traceback (most recent call last):
#   File "C:\Users\Gonzalo\PycharmProjects\Projecto_final-_data_analysis\.venv\Lib\site-packages\streamlit\dataframe_util.py", line 829, in convert_pandas_df_to_arrow_bytes
#     table = pa.Table.from_pandas(df)
#   File "pyarrow\\table.pxi", line 4795, in pyarrow.lib.Table.from_pandas
#   File "C:\Users\Gonzalo\PycharmProjects\Projecto_final-_data_analysis\.venv\Lib\site-packages\pyarrow\pandas_compat.py", line 637, in dataframe_to_arrays
#     arrays = [convert_column(c, f)
#               ~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Gonzalo\PycharmProjects\Projecto_final-_data_analysis\.venv\Lib\site-packages\pyarrow\pandas_compat.py", line 625, in convert_column
#     raise e
#   File "C:\Users\Gonzalo\PycharmProjects\Projecto_final-_data_analysis\.venv\Lib\site-packages\pyarrow\pandas_compat.py", line 619, in convert_column
#     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#   File "pyarrow\\array.pxi", line 365, in pyarrow.lib.array
#   File "pyarrow\\array.pxi", line 91, in pyarrow.lib._ndarray_to_array
#   File "pyarrow\\error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowInvalid: ("Could not convert dtype('float64') with type numpy.dtypes.Float64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object')
# 2025-11-30 20:50:38.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:38.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-30 20:50:39.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
