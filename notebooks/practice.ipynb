# %% [markdown]
# # Análisis previo
#
# ### ¿Que contiene el DataSet?
# En el dataset de esta última entrega nos encontramos con el database California Housing, que reúne información de distintas zonas del estado de California a partir del censo del año 1990. Cada fila representa un grupo de viviendas en una zona determinada y la variable principal que utilizaremos es "MedHouseVal" que indica el valor mediano de la vivienda en dolares. Además del valor de la vivienda, el dataset incluye otros datos como ingresos medianos de los hogares de la zona, edad mediana de las viviendas, promedio de habitaciones y dormitorios por vivienda, etc.
# Este tipo de información es útil porque permite relacionar el precio de las viviendas con factores económicos, demográficos y geográficos.
#
# ### Tipos de datos
# El dataset tiene más de 20.000 registros y 8 variables explicativas (algunas de las que mencionamos más arriba), todas numéricas, además de la variable objetivo. No se ven valores nulos en las columnas principales por tanto no se necesita hacer una limpieza de este tipo sobre datos incompletos, lo cual facilita la tarea, además de obtener directamente las variables ya catergorizadas.
#
# ### ¿Por que me interesa a mi?
# Desde la perspectiva de ser estudiante enfocado a la direccion de empresas, siempre intento pensar en como podría utilizar justamente este tipo de dataset, y a lo que llego, es que se puede aprovechar para analizar cómo se relacionan los precios de la vivienda con el nivel de ingresos y otras características de cada zona, identificar segmentos de mercado con viviendas más caras o más accesibles, detectar posibles oportunidades de inversión o desarrollo inmobiliario y pensar en estrategias de precios, segmentación de clientes o diseño de productos financieros adaptados a las características económicas y demográficas de cada área.
